# %% [markdown]
# Logistic Regression

# %%
# !pip install vaderSentiment
# %run /Untitled3.ipynb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.0 MB/s eta 0:00:00
# ...
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorizer: Converts the text into numerical form
tfidf = TfidfVectorizer(max_features=5000)  # We limit the number of features to 5000 for efficiency
X_tfidf = tfidf.fit_transform(df['clean_text'])  # Applies the TF-IDF transformation

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder and encode sentiment labels
encoder = LabelEncoder()
y = encoder.fit_transform(df['sentiment'])

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the model
model = LogisticRegression()

# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7074829931972789
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.24      0.38        38
#            1       0.00      0.00      0.00        14
#            2       0.69      1.00      0.82        95
#
#     accuracy                           0.71       147
#    macro avg       0.53      0.41      0.40       147
# weighted avg       0.68      0.71      0.63       147
#
# Confusion Matrix:
#  [[ 9  0 29]
#  [ 1  0 13]
#  [ 0  0 95]]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.model_selection import GridSearchCV

# Set up a parameter grid for hyperparameter tuning
param_grid = {'C': [0.1, 1, 10], 'max_iter': [100, 200]}

# Initialize GridSearchCV to tune the model
grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5)

# Fit the grid search
grid_search.fit(X_train, y_train)

# Print the best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'C': 10, 'max_iter': 100}

# %%
def predict_sentiment(new_text):
    # Preprocess the new text
    clean_text1 = clean_text(new_text)

    # Transform the new text using the same TF-IDF vectorizer
    new_text_tfidf = tfidf.transform([clean_text1])

    # Make the sentiment prediction using the trained model
    sentiment_score = model.predict(new_text_tfidf)

    # Convert the numerical label back to the original sentiment label
    sentiment_label = encoder.inverse_transform(sentiment_score)

    return sentiment_label[0]

# Example usage:
new_input = "I have a bad habit"
predicted_sentiment = predict_sentiment(new_input)

print(f"The predicted sentiment for the input text is: {predicted_sentiment}")
# Out:
# The predicted sentiment for the input text is: Negative
